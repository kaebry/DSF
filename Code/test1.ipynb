# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
df = pd.read_csv("../Data/daily_data.csv")
df.rename(columns={"Unnamed: 0": "datetime"}, inplace=True)

# %%
df = df.dropna()

# %%
# convert DateTime column into datetime format
df["datetime"] = pd.to_datetime(df['datetime'])
# set DateTime as index
df.set_index("datetime", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2887 entries, 2012-01-02 to 2019-11-27
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   2887 non-null   float64
#  1   suction_tension (40cm)   2887 non-null   float64
#  2   suction_tension (70cm)   2887 non-null   float64
#  3   water_temperature        2887 non-null   float64
#  4   barometric_pressure_qfe  2887 non-null   float64
#  5   dew_point                2887 non-null   float64
#  6   water_level              2887 non-null   float64
#  7   inflow_linth (m3/s)      2887 non-null   float64
#  8   outflow_limmat (m3/s)    2887 non-null   float64
#  9   precipitation (mm)       2887 non-null   float64
#  10  change_rate              2887 non-null   float64
#  11  Evapotranspiration (mm)  2887 non-null   float64
# dtypes: float64(12)
# memory usage: 293.2 KB

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(series, signif=0.05, name='', verbose=False):
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
for name, column in df.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
# C:\Users\lunam\AppData\Local\Temp\ipykernel_9860\1973961402.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, column in df.iteritems():
#     Augmented Dickey-Fuller Test on "suction_tension (20cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.4422
#  No. Lags Chosen       = 27
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "suction_tension (40cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.6122
#  No. Lags Chosen       = 10
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "suction_tension (70cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.7205
#  No. Lags Chosen       = 22
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "water_temperature"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.627
#  No. Lags Chosen       = 28
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "barometric_pressure_qfe"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.2194
#  No. Lags Chosen       = 21
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "dew_point"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.708
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "water_level"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3418
#  No. Lags Chosen       = 14
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "inflow_linth (m3/s)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1811
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "outflow_limmat (m3/s)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.3659
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "precipitation (mm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.8409
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "change_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -16.6916
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Evapotranspiration (mm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.6881
#  No. Lags Chosen       = 27
#  Critical value 1%     = -3.433
#  Critical value 5%     = -2.863
#  Critical value 10%    = -2.567
#  => P-Value = 0.0043. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
import pandas as pd

# %%
weather = pd.read_csv("Mythenquai_anually.csv")
soil = pd.read_csv("saugspannung_agg.csv")
water = pd.read_csv("waterdata_agg.csv")

# %%
water
# Out:
#                          datetime  Pegel Zurichsee  Pegel Obersee  \
# 0       2000-01-01 01:00:00+01:00          405.895            NaN
# 1       2000-01-01 02:00:00+01:00          405.894            NaN
# 2       2000-01-01 03:00:00+01:00          405.892            NaN
# 3       2000-01-01 04:00:00+01:00          405.890            NaN
# 4       2000-01-01 05:00:00+01:00          405.889            NaN
# ...                           ...              ...            ...
# 200466  2022-11-13 20:00:00+01:00          405.993        405.952
# 200467  2022-11-13 21:00:00+01:00          405.992        405.953
# 200468  2022-11-13 22:00:00+01:00          405.992        405.952
# 200469  2022-11-13 23:00:00+01:00          405.992        405.950
# 200470  2022-11-14 00:00:00+01:00          405.992        405.950
#
#         Abfluss Linth  Pegel Linth  Wasser_temp Linth  Abfluss Limmat  \
# 0              32.736      418.304               5.76          95.552
# ...

# %%
soil
# Out:
#                         datetime  Wädenswil (20cm)  Wädenswil (40cm)  \
# 0      2012-01-01 01:00:00+01:00              0.50              0.60
# 1      2012-01-01 02:00:00+01:00              0.60              0.70
# 2      2012-01-01 03:00:00+01:00              0.70              0.80
# 3      2012-01-01 04:00:00+01:00              0.80              0.80
# 4      2012-01-01 05:00:00+01:00              1.00              0.90
# ...                          ...               ...               ...
# 73844  2021-12-30 21:00:00+01:00              2.37              2.55
# 73845  2021-12-30 22:00:00+01:00              2.40              2.58
# 73846  2021-12-30 23:00:00+01:00              2.44              2.61
# 73847  2021-12-31 00:00:00+01:00              2.50              2.64
# 73848  2021-12-31 01:00:00+01:00              2.56              2.67
#
#        Wädenswil (70cm)
# 0                 1.000
# 1                 1.000
# 2                 1.200
# 3                 1.200
# ...

# %%
df_merged = pd.merge(pd.merge(soil, weather, how="left", on="datetime"), water, how="left", on="datetime")
df_merged
# Out:
#                         datetime  Wädenswil (20cm)  Wädenswil (40cm)  \
# 0      2012-01-01 01:00:00+01:00              0.50              0.60
# 1      2012-01-01 02:00:00+01:00              0.60              0.70
# 2      2012-01-01 03:00:00+01:00              0.70              0.80
# 3      2012-01-01 04:00:00+01:00              0.80              0.80
# 4      2012-01-01 05:00:00+01:00              1.00              0.90
# ...                          ...               ...               ...
# 73844  2021-12-30 21:00:00+01:00              2.37              2.55
# 73845  2021-12-30 22:00:00+01:00              2.40              2.58
# 73846  2021-12-30 23:00:00+01:00              2.44              2.61
# 73847  2021-12-31 00:00:00+01:00              2.50              2.64
# 73848  2021-12-31 01:00:00+01:00              2.56              2.67
#
#        Wädenswil (70cm)  air_temperature  water_temperature  \
# 0                 1.000         7.516667                5.9
# ...

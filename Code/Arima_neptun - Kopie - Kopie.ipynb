# %% [markdown]
# ## Time Series Models from the ARIMA Family

# %%
# load necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pmdarima as pm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from pmdarima.model_selection import train_test_split
from datetime import datetime, timedelta

# %%
## import and prepare montly data

monthly_data = pd.read_csv("../Data/clean_data/monthly_data.csv")
# convert DateTime column into datetime format
monthly_data["datetime"] = pd.to_datetime(monthly_data['datetime'])
# set DateTime as index
monthly_data.set_index("datetime", inplace=True)
water_monthly = monthly_data[["water_level"]]

## import and prepare weekly data

weekly_data = pd.read_csv("../Data/clean_data/weekly_data.csv")
# convert DateTime column into datetime format
weekly_data["datetime"] = pd.to_datetime(weekly_data['datetime'])
# set DateTime as index
weekly_data.set_index("datetime", inplace=True)
water_weekly = weekly_data[["water_level"]]

# %%
# function for calculating different performance measures

from sklearn.metrics import mean_absolute_error as mae
import numpy as np
from sklearn.metrics import r2_score

def mean_errors(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    MAE = mae(actual, pred)
    MSE = np.square(np.subtract(actual,pred)).mean()
    MAPE = np.mean(np.abs((actual - pred) / actual)) * 100
    R2_score = r2_score(actual, pred)
    return print("MAE: {} \nMSE: {} \nMAPE: {} \nR2: {}".format(MAE, MSE, MAPE, R2_score))

# %%
# function for Arima model with walking forward validation

def walk_forward_validation_ARIMA(train, test, order):
    window=1
    forecast_series = pd.DataFrame(index=test.index, columns=[x for x in range(window)])
    training_data = train.copy()
    for i in test.index:
        model = ARIMA(training_data, order=order).fit()
        forecast_series.loc[i] = model.forecast(window)[0]
        training_data.loc[i] = test.loc[i]
        columns = [f'yt+{x}' for x in forecast_series.columns]
    forecast_series.columns = columns
    return forecast_series.astype(float), model

# %%
# function for Sarima model with walking forward validation

def walk_forward_validation_SARIMA(train, test, order, seasonalorder):
    window=1
    forecast_series = pd.DataFrame(index=test.index, columns=[x for x in range(window)])
    training_data = train.copy()
    for i in test.index:
        model = ARIMA(training_data, order=order, seasonal_order=seasonalorder).fit()
        forecast_series.loc[i] = model.forecast(window)[0]
        training_data.loc[i] = test.loc[i]
        columns = [f'yt+{x}' for x in forecast_series.columns]
    forecast_series.columns = columns
    return forecast_series.astype(float), model.summary()

# %% [markdown]
# # Monthly Data

# %% [markdown]
# Decompose montly data into trend, serial and white noise components

# %%
# decompose the monthly data to find out trends and and seasonalites 
seasonal_decompose(water_monthly).plot()

# %% [markdown]
# Checking for stationarity using the Partial Autocorrelation Plot

# %%
# plot autocorrelation and partial autocorrelation
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(water_monthly, lags=46, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(water_monthly, lags=46, ax=ax[1])
plt.show()

# the first two lags of the partial autocorrelation are still significant which suggests that the time series is non stationary
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Checking for stationarity using the ADF test

# %%
# check for stationarity with the ADF test using the adfuller function
from statsmodels.tsa.stattools import adfuller
adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(water_monthly)
print('ADF test statistic:', adf)
print('ADF p-values:', pval)
print('ADF number of lags used:', usedlag)
print('ADF number of observations:', nobs)
print('ADF critical values:', crit_vals)
print('ADF best information criterion:', icbest)

# the p value is above 0.05, so the null hypthesis gets rejected and the water level time series is non stationary
# Out:
# ADF test statistic: -2.4233565623253295
# ADF p-values: 0.13525240781777587
# ADF number of lags used: 10
# ADF number of observations: 84
# ADF critical values: {'1%': -3.510711795769895, '5%': -2.8966159448223734, '10%': -2.5854823866213152}
# ADF best information criterion: -210.3294454437903

# %% [markdown]
# Differencing

# %%
# differencing water level data to make it stationary 
prev_monthly_value = water_monthly.shift()
differenced_monthly = water_monthly - prev_monthly_value
differenced_monthly.plot()
# Out:
# <AxesSubplot: xlabel='datetime'>

# %% [markdown]
# check for stationarity again

# %%
# ADF test on differenced data, the p value is now below 0.05 and suggests that the time series is now stationary after differencing once
adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(differenced_monthly.dropna())
print('ADF test statistic:', adf)
print('ADF p-values:', pval)
print('ADF number of lags used:', usedlag)
print('ADF number of observations:', nobs)
print('ADF critical values:', crit_vals)
print('ADF best information criterion:', icbest)
# Out:
# ADF test statistic: -3.117132704753469
# ADF p-values: 0.025310999379347113
# ADF number of lags used: 12
# ADF number of observations: 81
# ADF critical values: {'1%': -3.5137900174243235, '5%': -2.8979433868293945, '10%': -2.5861907285474777}
# ADF best information criterion: -203.27107481438185

# %% [markdown]
# # Auto Arima Model Monthly

# %%
# split the differenced, stationary monthly data into training and test dataset, the data from 2019 onwards is selected as global testdata 
train_diff, test_diff = train_test_split(differenced_monthly, train_size=84)

# %%
# split training dataset into validation and train data
train_diff_val, test_diff_val = train_test_split(train_diff, train_size=72)

# %%
# instantiate and fit the autoarima model with the differenced trainings data 

# we are using the differenced data because the auto arima model doesn´t differentiates the data to make it stationary (d=0) and in this case 
# the predictions for the unseen training data are quite linear and do not really match the fluctuations of the water level. 
# by using the differenced data we circumvent this problem but get instead the change rate on the plot and not the absolut water level data

# seasonal is set to true since we have seasonality and m is the periocidy of the data since it is monthly data
auto_arima_model = pm.auto_arima(train_diff_val.dropna(), seasonal=True, m=12)
preds = auto_arima_model.predict(test_diff_val.shape[0])
# predict the test data with the auto-ARIMA-model
preds_auto_arima = auto_arima_model.predict(test_diff_val.shape[0])
# display the parameters the auto_arima function selected 
print(auto_arima_model)

# plot the actual and predicted change rate of the water level for validating model
plt.plot(train_diff.index, train_diff)
plt.plot(test_diff_val.index, preds_auto_arima)
plt.show()

# print different errors to evaluate performance
print(mean_errors(test_diff_val, preds_auto_arima))
# Out:
#  ARIMA(1,0,1)(2,0,0)[12] intercept
# MAE: 0.08980200857188114
# MSE: 0.014179525778046495
# MAPE: 246.36805603674125
# R2: 0.0022497174710572887
# None

# %% [markdown]
# Global Testing

# %%
# make a forecast for the unseen testdata for 2019 to see how well the Auto-ARIMA model performs for unseen data
forecast_auto_arima = auto_arima_model.predict(test_diff.shape[0])

# plot the actual and predicted change rate of the water level for validating model
plt.plot(test_diff.index, test_diff)
plt.plot(test_diff.index, forecast_auto_arima)
plt.show()

# print different errors to evaluate performance
print(mean_errors(test_diff, forecast_auto_arima))
# Out:
# MAE: 0.06001818042186843
# MSE: 0.009210775441686886
# MAPE: 137.31710678582624
# R2: 0.2745214977812531
# None

# %% [markdown]
# # Arima Model Monthly

# %%
# train test split for SARIMA model
train, test = train_test_split(water_monthly, train_size=84)
# split the trainings data into training and validation data
train_val, test_val = train_test_split(train, train_size=60)

# %%
# instantiate and fit arima model manually with seasonal parameters
# we chose d and D = 1 because the series is non stationary
# we chose p adn P = 2 because the first lags in the ACF and PACF plots have significant spikes, q dn Q = 1 because there were also 
# negative autocorrelations. The ultimate combination of the seven parameters was choosen by varying some of the parameters until we found the
# model with the lowest mean errors and the highest R2 
wf_arima_preds, model= walk_forward_validation_ARIMA(train_val, test_val, (2,1,1))

# plotting actual and predicted water level
plt.plot(train.index, train)
plt.plot(test_val.index, wf_arima_preds)
plt.show()

# print performance indicators
print(mean_errors(test_val, wf_arima_preds))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MAE: 0.06547308818493036
# MSE: 0.006965666859694388
# MAPE: 0.016131452151471003
# R2: 0.3202370107626513
# None

# %%
def walk_forward_forecast_ARIMA(train, test, modelo):
    window=1
    forecast_series = pd.DataFrame(index=test.index, columns=[x for x in range(window)])
    training_data = train.copy()
    for i in test.index:
        model = ARIMA(training_data, order=order).fit()
        forecast_series.loc[i] = model.forecast(window)[0]
        training_data.loc[i] = test.loc[i]
        columns = [f'yt+{x}' for x in forecast_series.columns]
    forecast_series.columns = columns
    return forecast_series.astype(float), model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            water_level   No. Observations:                   83
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                  90.460
# Date:                Fri, 02 Dec 2022   AIC                           -172.920
# Time:                        15:01:20   BIC                           -163.293
# Sample:                    01-31-2012   HQIC                          -169.055
#                          - 11-30-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9720      0.115      8.436      0.000       0.746       1.198
# ar.L2         -0.4029      0.120     -3.346      0.001      -0.639      -0.167
# ma.L1         -0.9994      5.907     -0.169      0.866     -12.577      10.579
# sigma2         0.0062      0.036      0.170      0.865      -0.065       0.077
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.65   Jarque-Bera (JB):                 0.04
# Prob(Q):                              0.42   Prob(JB):                         0.98
# Heteroskedasticity (H):               0.73   Skew:                            -0.04
# Prob(H) (two-sided):                  0.42   Kurtosis:                         3.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
new_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            water_level   No. Observations:                   94
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 102.624
# Date:                Fri, 02 Dec 2022   AIC                           -197.248
# Time:                        15:01:35   BIC                           -187.117
# Sample:                    01-31-2012   HQIC                          -193.157
#                          - 10-31-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9610      0.107      9.023      0.000       0.752       1.170
# ar.L2         -0.3759      0.109     -3.461      0.001      -0.589      -0.163
# ma.L1         -0.9999     37.678     -0.027      0.979     -74.848      72.848
# sigma2         0.0062      0.233      0.027      0.979      -0.450       0.463
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.52   Jarque-Bera (JB):                 0.27
# Prob(Q):                              0.47   Prob(JB):                         0.87
# Heteroskedasticity (H):               0.78   Skew:                            -0.13
# Prob(H) (two-sided):                  0.50   Kurtosis:                         2.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
lol, new_model = walk_forward_validation_ARIMA(train, test, (2,1,1))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# global testing

# %%
# use the unseen testing set to evaluate the Sarima models´ performance for unseen data from 2019
# in the validation procedure it performed better than the Autoarima model

# forecast future values using the model
forecast_arima_manual = model.forecast(len(test))

# plotting actual and forcasted water level for 2019
plt.plot(test.index, test)
plt.plot(test.index, forecast_arima_manual)
plt.plot(test.index, lol)
plt.show()

# print performance indicators
print(mean_errors(test, forecast_arima_manual))
print(mean_errors(test, lol))

# the Sarima Model seems to perform worse under unseen data than the Autoarima model. There is the possibility that the model is overfitted
# Out:
# MAE: 0.0942627714257624
# MSE: 0.01798099479991459
# MAPE: 0.02946158859084015
# R2: 0.2080915879667472
# None
# MAE: 0.06010115649675382
# MSE: 0.0056472127226533326
# MAPE: 0.014806252345016813
# R2: 0.6016136922697857
# None

# %% [markdown]
# # SARIMA Model Monthly

# %%
# model with Sarimax
import statsmodels.api as sm
model_max = sm.tsa.statespace.SARIMAX(train_val, order=(2,1,1), seasonal_order=(2,1,1,12)).fit(max_iter=50, method='powell')
# predicting with model
preds_max = model_max.forecast(len(test_val))
# plotting prediction and actual values
plt.plot(train.index, train)
plt.plot(test_val.index, preds_max)
plt.show()

print(mean_errors(test_val,preds_max))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method powell is: xtol, ftol, maxfun, start_direc. The list of unsupported keyword arguments passed include: max_iter. After release 0.14, this will raise.
#   warnings.warn(
# Optimization terminated successfully.
#          Current function value: -1.074975
#          Iterations: 9
#          Function evaluations: 845
# MAE: 0.04603482033893632
# MSE: 0.016472493759291204
# MAPE: 0.02518388522207045
# R2: 0.550160214329602
# None

# %% [markdown]
# Global Testing

# %%
# forecast future values using the model
forecast_sarimax = model_max.forecast(len(test))

# plotting actual and forcasted water level for 2019
plt.plot(test.index, test)
plt.plot(test.index, forecast_sarimax)
plt.show()

# print performance indicators
print(mean_errors(test, forecast_sarimax))

# Performs slightly better than the Sarima, maybe due to other parameter
# Out:
# MAE: 0.058583942077224165
# MSE: 0.02453332505017901
# MAPE: 0.03170779349338945
# R2: 0.6480406677435735
# None

# %%
# plot ACF and PACF curve for residuals of SARIMAX model

res = model_max.resid

fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(res, lags=35, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(res, lags=35, ax=ax[1])
plt.show()
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# data = entire dataset
# n_test = point where data is split into training and test sets
def walk_forward_validation(data, n_test):
    predictions = np.array([])
    mape_list = []
    train, test = data[:n_test], data[n_test:]
    day_list = [6,12,18,24] # weeks 1,2,3,4    
    for i in day_list:
        # Fit model to training data
        model = sm.tsa.statespace.SARIMAX(train, order=(2,1,2), seasonal_order=(2,1,1,12)).fit(max_iter = 50, method = 'powell')
                
        # Forecast daily loads for week i
        forecast = model.get_forecast(steps = 6)
        predictions = np.concatenate(predictions, forecast, axis=None)        # Calculate MAPE and add to mape_list
        j = i-6
        mape_score = (abs(test[j:i] - predictions[j:i])/test[j:i])*100
        mape_mean = mape_score.mean()
        mape_list.append(mape_mean)        # Add week i to training data for next loop
        train = np.concatenate((train, test[j:i]), axis=None)
    return predictions, mape_list

# %%
walk_forward_validation(water,72)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lucal\Documents\HSG\7._Semester\DSF\Project\DSF\Code\Arima_neptun - Kopie.ipynb Zelle 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucal/Documents/HSG/7._Semester/DSF/Project/DSF/Code/Arima_neptun%20-%20Kopie.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> walk_forward_validation(water,72)
#
# NameError: name 'water' is not defined

# %%
residuals = model_manual_fit.resid[1:]
fig, ax = plt.subplots(1,2)
residuals.plot(title='Residuals', ax=ax[0])
residuals.plot(title='Density', kind='kde', ax=ax[1])
plt.show()

# %%
import statsmodels.api as sm
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(residuals, lags=46, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(residuals, lags=46, ax=ax[1])
plt.show()

# %% [markdown]
# # Models for Weekly Data

# %%
# decompose the monthly data to find out trends and and seasonalites 
seasonal_decompose(water_weekly,  period=13).plot()

# setting period to 13 to find quarterly seasonalities

# %%
# plot autocorrelation and partial autocorrelation
fig, ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(water_weekly, lags=52, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(water_weekly, lags=52, ax=ax[1])
plt.show()

# %%
# check for stationarity with the ADF test
from statsmodels.tsa.stattools import adfuller
adf, pval, usedlag, nobs, crit_vals, icbest =  adfuller(water_weekly)
print('ADF test statistic:', adf)
print('ADF p-values:', pval)
print('ADF number of lags used:', usedlag)
print('ADF number of observations:', nobs)
print('ADF critical values:', crit_vals)
print('ADF best information criterion:', icbest)
# Out:
# ADF test statistic: -4.982589900225232
# ADF p-values: 2.4022962615431937e-05
# ADF number of lags used: 5
# ADF number of observations: 408
# ADF critical values: {'1%': -3.446479704252724, '5%': -2.8686500930967354, '10%': -2.5705574627547096}
# ADF best information criterion: -1243.505402180334

# %%
train_we, test_we = train_test_split(water_weekly, train_size=366)

# %%
train_all, test_all = train_test_split(weekly_data, train_size=314)

# %%
# instantiate and fit the autoarima model with the weekly trainings data 

# seasonal is set to true since we have seasonality and m is the periocidy of the data since it is weekly data
auto_arima_we = pm.auto_arima(train_we.dropna(), seasonal=True, m=52)
preds = auto_arima_we.predict(test_we.shape[0])
# predict the test data with the auto-ARIMA-model
preds_auto_we = auto_arima_we.predict(test_we.shape[0])
# display the parameters the auto_arima function selected 
print(auto_arima_we)

# plot the actual and predicted change rate of the water level
plt.plot(water_weekly.index, water_weekly)
plt.plot(water_weekly.index[314:], preds_auto_we)
plt.show()

# print different errors to evaluate performance
print(mean_errors(test_we, preds_auto_we))

# %%
# plot the actual and predicted change rate of the water level
plt.plot(water_weekly.index, water_weekly)
plt.plot(water_weekly.index[314:], preds_auto_we)
plt.show()

# print different errors to evaluate performance
print(mean_errors(test_we, preds_auto_we))
# Out:
# MAE: 0.09674969830158034
# MSE: 0.014064142062946346
# MAPE: 0.02398221349722815
# R2: -0.008001338711256079
# None

# %% [markdown]
# # Seasonal ARIMA Model Weekly

# %%
# split training data into training and testing set for validation
train_val, test_val = train_test_split(train_we, train_size=314)

# %%
arima_manual_we = ARIMA(train_val, order=(2,0,0), seasonal_order=(1,1,2,52))
arima_we_fit = arima_manual_we.fit()
# predict future values using the model
preds_arima_we = arima_we_fit.forecast(len(test_val))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# plotting actual and predicted water level
plt.plot(train_we.index, train_we)
plt.plot(train_we.index[314:], preds_arima_we)
plt.show()

# print performance indicators
print(mean_errors(test_val, preds_arima_we))
# Out:
# MAE: 0.06265348213917193
# MSE: 0.0189987232566919
# MAPE: 0.027197461139701864
# R2: 0.28430682789665207
# None

# %%
forecast_arima_we = arima_we_fit.forecast(len(test_we))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# plotting actual and predicted water level
plt.plot(test_we.index, test_we)
plt.plot(test_we.index, forecast_arima_we)
plt.show()

# print performance indicators
print(mean_errors(test_we, forecast_arima_we))
# Out:
# MAE: 0.043773334726672886
# MSE: 0.022880384407845705
# MAPE: 0.029413829868540072
# R2: 0.8103779835442417
# None

# %% [markdown]
# # SARIMA MODEL Weekly

# %%
# model with Sarimax
import statsmodels.api as sm
model_max_we = sm.tsa.statespace.SARIMAX(endog=train_we, exog=train_all["precipitation (mm)"], 
order=(2,0,0), seasonal_order=(2,1,1,52)).fit(max_iter=50, method='powell')
# predicting with model
preds_max_we = model_max.forecast(len(test_we))
# plotting prediction and actual values
plt.plot(water_weekly.index, water_weekly)
plt.plot(water_weekly.index[314:], preds_max_we)
plt.show()

print(mean_errors(test_we,preds_max_we))
# Out:
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\lucal\miniconda3\envs\dsf\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method powell is: xtol, ftol, maxfun, start_direc. The list of unsupported keyword arguments passed include: max_iter. After release 0.14, this will raise.
#   warnings.warn(
# Optimization terminated successfully.
#          Current function value: -1.188735
#          Iterations: 10
#          Function evaluations: 938
# MAE: 0.13231115551780648
# MSE: 0.022339168692540358
# MAPE: 0.02973220238990858
# R2: -0.8080567904468914
# None

# %%
weekly_data["outflow_limmat (m3/s)"]#.plot()
# Out:
# datetime
# 2012-01-01 00:00:00+01:00    141.302696
# 2012-01-08 00:00:00+01:00    130.655173
# 2012-01-15 00:00:00+01:00     98.241024
# 2012-01-22 00:00:00+01:00     85.367494
# 2012-01-29 00:00:00+01:00    101.413720
#                                 ...
# 2019-11-03 00:00:00+01:00     85.093263
# 2019-11-10 00:00:00+01:00     99.203155
# 2019-11-17 00:00:00+01:00     92.942345
# 2019-11-24 00:00:00+01:00     78.785926
# 2019-12-01 00:00:00+01:00     67.687139
# Name: outflow_limmat (m3/s), Length: 414, dtype: float64

# %%
weekly_data["water_level"].plot()
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
from scipy.fft import fft, ifft

# %%
N = len(water_weekly)
yf = fft(water_weekly)
xf = fftfreq(N, 1 / SAMPLE_RATE)

plt.plot(xf, np.abs(yf))
plt.show()
# Out:
# array([[405.91195652-0.j],
#        [405.92603571-0.j],
#        [405.85668056-0.j],
#        [405.81148214-0.j],
#        [405.82859524-0.j],
#        [405.77660714-0.j],
#        [405.75137923-0.j],
#        [405.71587897-0.j],
#        [405.73575397-0.j],
#        [405.69655258-0.j],
#        [405.70915675-0.j],
#        [405.74302579-0.j],
#        [405.77003062-0.j],
#        [405.84041667-0.j],
#        [405.89615327-0.j],
#        [405.9371999 -0.j],
#        [405.96331349-0.j],
#        [406.00608135-0.j],
#        [406.00415675-0.j],
#        [406.01722222-0.j],
#        [406.03949405-0.j],
#        [406.02286706-0.j],
#        [406.03560313-0.j],
#        [406.04460592-0.j],
#        [406.04941818-0.j],
#        [406.01201911-0.j],
#        [405.99837951-0.j],
#        [405.99344962-0.j],
#        [405.97493428-0.j],
#        [405.92864087-0.j],
#        [405.90584416-0.j],
#        [405.87544341-0.j],
#        [405.85090476-0.j],
#        [405.81845887-0.j],
#        [405.81314633-0.j],
#        [405.88065574-0.j],
#        [405.98807971-0.j],
#        [405.97459325-0.j],
#        [405.94518699-0.j],
#        [405.94978692-0.j],
#        [405.9504707 -0.j],
#        [405.92059666-0.j],
#        [405.90675682-0.j],
#        [405.84878401-0.j],
#        [405.85465623-0.j],
#        [405.84172619-0.j],
#        [405.79551587-0.j],
#        [405.72926587-0.j],
#        [405.71769841-0.j],
#        [405.9046131 -0.j],
#        [405.91661706-0.j],
#        [405.88155754-0.j],
#        [405.96008929-0.j],
#        [405.83797188-0.j],
#        [405.8388869 -0.j],
#        [405.814     -0.j],
#        [405.77698214-0.j],
#        [405.74034722-0.j],
#        [405.73820264-0.j],
#        [405.71805556-0.j],
#        [405.68965278-0.j],
#        [405.67727183-0.j],
#        [405.70500992-0.j],
#        [405.78871032-0.j],
#        [405.88106151-0.j],
#        [405.85874827-0.j],
#        [405.90157738-0.j],
#        [405.93537698-0.j],
#        [405.93848214-0.j],
#        [405.96198413-0.j],
#        [405.98735944-0.j],
#        [406.00147775-0.j],
#        [405.99269841-0.j],
#        [406.12290675-0.j],
#        [406.05963294-0.j],
#        [406.06790675-0.j],
#        [406.12816468-0.j],
#        [406.10530754-0.j],
#        [406.05744048-0.j],
#        [406.03479167-0.j],
#        [406.02238095-0.j],
#        [406.00928571-0.j],
#        [406.00253968-0.j],
#        [406.03047619-0.j],
#        [406.03547619-0.j],
#        [406.0787996 -0.j],
#        [406.11987103-0.j],
#        [406.08104167-0.j],
#        [406.05126984-0.j],
#        [406.08237103-0.j],
#        [406.0153373 -0.j],
#        [406.00478175-0.j],
#        [406.01697421-0.j],
#        [406.08925595-0.j],
#        [406.0360754 -0.j],
#        [405.98192121-0.j],
#        [405.98177273-0.j],
#        [406.00595343-0.j],
#        [405.97356276-0.j],
#        [405.9587205 -0.j],
#        [405.94743056-0.j]])

# %%
# Korstanje, J. 2022.  How to Select a Model For Your Time Series Prediction Task. Retrieved from: 
# https://neptune.ai/blog/select-model-for-time-series-prediction-task 

# Graves, A. 2020. Time Series Forecasting with a SARIMA Model. Retrieved from: 
# https://towardsdatascience.com/time-series-forecasting-with-a-sarima-model-db051b7ae459

#

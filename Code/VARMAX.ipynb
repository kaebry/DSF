# %% [markdown]
# # Walking-Forward VAR Model with all Variables - Weekly Data

# %%
#import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') 

#import statsmodels
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from pmdarima.model_selection import train_test_split

# %%
dvar1 = pd.read_csv("../Data/clean_data/weekly_data.csv")
dvar1
# Out:
#        datetime  suction_tension (20cm)  suction_tension (40cm)  \
# 0    2012-01-08                1.864286                1.509524
# 1    2012-01-15                3.045833                2.662500
# 2    2012-01-22                3.732738                2.593155
# 3    2012-01-29                1.999405                1.724405
# 4    2012-02-05                3.800000                2.969048
# ..          ...                     ...                     ...
# 408  2019-11-03                3.469347                2.576207
# 409  2019-11-10                2.369476                1.514638
# 410  2019-11-17                3.027560                2.366860
# 411  2019-11-24                3.563155                2.414583
# 412  2019-12-01                4.767257                3.531424
#
#      suction_tension (70cm)  water_temperature  barometric_pressure_qfe  \
# 0                  1.657143           5.718254               972.342540
# 1                  2.254167           5.230734               981.800595
# 2                  2.293155           4.960377               975.973750
# 3                  1.831548           5.042589               973.659752
# 4                  2.390476           4.035357               975.891310
# ..                      ...                ...                      ...
# 408                1.121059          14.486458               964.152153
# 409                0.815091          13.225020               957.176825
# 410                1.946473          11.813165               957.502272
# 411                3.232589          10.580665               960.705625
# 412                3.827292          10.075880               961.537292
#
#      dew_point  water_level  inflow_linth (m3/s)  outflow_limmat (m3/s)  \
# 0     1.582381   405.925937            42.463125             130.712589
# 1    -0.039742   405.856155            41.259768              97.885887
# 2    -0.223948   405.811720            31.684387              85.611571
# 3     1.402569   405.828179            38.195262             101.169554
# 4    -9.414226   405.776389            38.501393              81.974750
# ..         ...          ...                  ...                    ...
# 408   8.988046   405.981652            49.719399              98.548613
# 409   4.898849   406.003480            53.301202              99.244786
# 410   1.784901   405.973247            49.496952              92.764923
# 411   2.868562   405.958633            46.694750              78.699708
# 412   5.354398   405.967396            41.137681              83.660458
#
#      precipitation (mm)  Evapotranspiration (mm)  change_rate
# 0                  50.2                     0.59          NaN
# 1                   0.0                     0.72    -0.000172
# 2                  40.1                     0.89    -0.000109
# 3                  13.7                     0.19     0.000041
# 4                   1.0                     0.70    -0.000128
# ..                  ...                      ...          ...
# 408                35.8                     0.60     0.000031
# 409                20.6                     1.35     0.000054
# 410                 5.4                     1.63    -0.000074
# 411                 0.0                     1.14    -0.000036
# 412                28.7                     0.65     0.000022
#
# [413 rows x 13 columns]

# %%
dvar1 = dvar1.dropna()

# %%
# convert DateTime column into datetime format
dvar1["datetime"] = pd.to_datetime(dvar1['datetime'])
# set DateTime as index
dvar1.set_index("datetime", inplace=True)
dvar1.info()
dvar1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 412 entries, 2012-01-15 to 2019-12-01
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   412 non-null    float64
#  1   suction_tension (40cm)   412 non-null    float64
#  2   suction_tension (70cm)   412 non-null    float64
#  3   water_temperature        412 non-null    float64
#  4   barometric_pressure_qfe  412 non-null    float64
#  5   dew_point                412 non-null    float64
#  6   water_level              412 non-null    float64
#  7   inflow_linth (m3/s)      412 non-null    float64
#  8   outflow_limmat (m3/s)    412 non-null    float64
#  9   precipitation (mm)       412 non-null    float64
#  10  Evapotranspiration (mm)  412 non-null    float64
#  11  change_rate              412 non-null    float64
# dtypes: float64(12)
# memory usage: 41.8 KB
#             suction_tension (20cm)  suction_tension (40cm)  \
# datetime
# 2012-01-15                3.045833                2.662500
# 2012-01-22                3.732738                2.593155
# 2012-01-29                1.999405                1.724405
# 2012-02-05                3.800000                2.969048
# 2012-02-12               27.794643                4.252679
# ...                            ...                     ...
# 2019-11-03                3.469347                2.576207
# 2019-11-10                2.369476                1.514638
# 2019-11-17                3.027560                2.366860
# 2019-11-24                3.563155                2.414583
# 2019-12-01                4.767257                3.531424
#
#             suction_tension (70cm)  water_temperature  \
# datetime
# 2012-01-15                2.254167           5.230734
# 2012-01-22                2.293155           4.960377
# 2012-01-29                1.831548           5.042589
# 2012-02-05                2.390476           4.035357
# 2012-02-12                2.889286           3.024345
# ...                            ...                ...
# 2019-11-03                1.121059          14.486458
# 2019-11-10                0.815091          13.225020
# 2019-11-17                1.946473          11.813165
# 2019-11-24                3.232589          10.580665
# 2019-12-01                3.827292          10.075880
#
#             barometric_pressure_qfe  dew_point  water_level  \
# datetime
# 2012-01-15               981.800595  -0.039742   405.856155
# 2012-01-22               975.973750  -0.223948   405.811720
# 2012-01-29               973.659752   1.402569   405.828179
# 2012-02-05               975.891310  -9.414226   405.776389
# 2012-02-12               980.527917 -12.032123   405.751361
# ...                             ...        ...          ...
# 2019-11-03               964.152153   8.988046   405.981652
# 2019-11-10               957.176825   4.898849   406.003480
# 2019-11-17               957.502272   1.784901   405.973247
# 2019-11-24               960.705625   2.868562   405.958633
# 2019-12-01               961.537292   5.354398   405.967396
#
#             inflow_linth (m3/s)  outflow_limmat (m3/s)  precipitation (mm)  \
# datetime
# 2012-01-15            41.259768              97.885887                 0.0
# 2012-01-22            31.684387              85.611571                40.1
# 2012-01-29            38.195262             101.169554                13.7
# 2012-02-05            38.501393              81.974750                 1.0
# 2012-02-12            40.779726              78.217399                 0.0
# ...                         ...                    ...                 ...
# 2019-11-03            49.719399              98.548613                35.8
# 2019-11-10            53.301202              99.244786                20.6
# 2019-11-17            49.496952              92.764923                 5.4
# 2019-11-24            46.694750              78.699708                 0.0
# 2019-12-01            41.137681              83.660458                28.7
#
#             Evapotranspiration (mm)  change_rate
# datetime
# 2012-01-15                     0.72    -0.000172
# 2012-01-22                     0.89    -0.000109
# 2012-01-29                     0.19     0.000041
# 2012-02-05                     0.70    -0.000128
# 2012-02-12                     0.80    -0.000062
# ...                             ...          ...
# 2019-11-03                     0.60     0.000031
# 2019-11-10                     1.35     0.000054
# 2019-11-17                     1.63    -0.000074
# 2019-11-24                     1.14    -0.000036
# 2019-12-01                     0.65     0.000022
#
# [412 rows x 12 columns]

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(series, signif=0.05, name='', verbose=False):
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
for name, column in dvar1.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "suction_tension (20cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.7781
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "suction_tension (40cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.4793
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "suction_tension (70cm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.5282
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0002. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "water_temperature"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.5263
#  No. Lags Chosen       = 15
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "barometric_pressure_qfe"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.1761
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "dew_point"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.2336
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "water_level"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1335
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "inflow_linth (m3/s)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.641
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "outflow_limmat (m3/s)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.7475
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "precipitation (mm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.8783
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Evapotranspiration (mm)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.3489
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.447
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "change_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.7294
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.446
#  Critical value 5%     = -2.869
#  Critical value 10%    = -2.571
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# As we can see all variables are stationary. However, when we controlled the monthly data, some variables turned out not to be stationary. Therefore we are going to difference for security.

# %% [markdown]
# # Split the data into train, validation and test set.

# %%
df = dvar1.drop(['water_temperature', 'suction_tension (20cm)', 'suction_tension (40cm)', 'suction_tension (70cm)', 'barometric_pressure_qfe', 'dew_point', 'Evapotranspiration (mm)', 'change_rate'], axis=1)
df
# Out:
#             water_level  inflow_linth (m3/s)  outflow_limmat (m3/s)  \
# datetime
# 2012-01-15   405.856155            41.259768              97.885887
# 2012-01-22   405.811720            31.684387              85.611571
# 2012-01-29   405.828179            38.195262             101.169554
# 2012-02-05   405.776389            38.501393              81.974750
# 2012-02-12   405.751361            40.779726              78.217399
# ...                 ...                  ...                    ...
# 2019-11-03   405.981652            49.719399              98.548613
# 2019-11-10   406.003480            53.301202              99.244786
# 2019-11-17   405.973247            49.496952              92.764923
# 2019-11-24   405.958633            46.694750              78.699708
# 2019-12-01   405.967396            41.137681              83.660458
#
#             precipitation (mm)
# datetime
# 2012-01-15                 0.0
# 2012-01-22                40.1
# 2012-01-29                13.7
# 2012-02-05                 1.0
# 2012-02-12                 0.0
# ...                        ...
# 2019-11-03                35.8
# 2019-11-10                20.6
# 2019-11-17                 5.4
# 2019-11-24                 0.0
# 2019-12-01                28.7
#
# [412 rows x 4 columns]

# %%
train_val, test_val = train_test_split(df, train_size=314)

# %%
train_all, test_pred = train_test_split(df, train_size=364)

# %%
var_model = VARMAX(train_val, order=(4,0),enforce_stationarity= True)
fitted_model = var_model.fit(disp=False)
print(fitted_model.summary())
# Out:
#                                                              Statespace Model Results
# =================================================================================================================================================
# Dep. Variable:     ['water_level', 'inflow_linth (m3/s)', 'outflow_limmat (m3/s)', 'precipitation (mm)']   No. Observations:                  314
# Model:                                                                                            VAR(4)   Log Likelihood               -3177.665
#                                                                                              + intercept   AIC                           6511.330
# Date:                                                                                   Fri, 02 Dec 2022   BIC                           6803.783
# Time:                                                                                           19:48:18   HQIC                          6628.189
# Sample:                                                                                       01-15-2012
#                                                                                             - 01-14-2018
# Covariance Type:                                                                                     opg
# ==================================================================================================
# Ljung-Box (L1) (Q):     0.02, 0.00, 0.01, 0.04   Jarque-Bera (JB):   463.28, 788.39, 58.78, 107.32
# Prob(Q):                0.88, 0.97, 0.92, 0.85   Prob(JB):                  0.00, 0.00, 0.00, 0.00
# Heteroskedasticity (H): 0.65, 0.53, 0.82, 1.13   Skew:                      1.13, 0.97, 0.77, 0.84
# Prob(H) (two-sided):    0.03, 0.00, 0.32, 0.52   Kurtosis:                 8.50, 10.52, 4.46, 5.31
#                               Results for equation water_level
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                   68.6800     11.871      5.785      0.000      45.412      91.948
# L1.water_level               1.0077      0.062     16.203      0.000       0.886       1.130
# L1.inflow_linth (m3/s)       0.0017      0.000      3.702      0.000       0.001       0.003
# L1.outflow_limmat (m3/s)    -0.0012      0.000     -4.700      0.000      -0.002      -0.001
# L1.precipitation (mm)        0.0009      0.000      3.939      0.000       0.000       0.001
# L2.water_level              -0.0421      0.090     -0.468      0.640      -0.218       0.134
# L2.inflow_linth (m3/s)      -0.0006      0.001     -0.940      0.347      -0.002       0.001
# L2.outflow_limmat (m3/s)  9.268e-05      0.000      0.250      0.803      -0.001       0.001
# L2.precipitation (mm)       -0.0001      0.000     -0.509      0.611      -0.001       0.000
# L3.water_level              -0.0548      0.133     -0.413      0.680      -0.315       0.205
# L3.inflow_linth (m3/s)      -0.0001      0.001     -0.114      0.909      -0.002       0.002
# L3.outflow_limmat (m3/s)     0.0002      0.000      0.476      0.634      -0.001       0.001
# L3.precipitation (mm)        0.0002      0.000      0.776      0.438      -0.000       0.001
# L4.water_level              -0.0800      0.091     -0.884      0.377      -0.258       0.097
# L4.inflow_linth (m3/s)       0.0003      0.001      0.518      0.605      -0.001       0.002
# L4.outflow_limmat (m3/s)  7.924e-05      0.000      0.267      0.789      -0.001       0.001
# L4.precipitation (mm)        0.0002      0.000      0.608      0.543      -0.000       0.001
#                           Results for equation inflow_linth (m3/s)
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                 6783.6536      0.485    1.4e+04      0.000    6782.702    6784.605
# L1.water_level             -15.6739     18.080     -0.867      0.386     -51.110      19.762
# L1.inflow_linth (m3/s)       1.0721      0.124      8.661      0.000       0.830       1.315
# L1.outflow_limmat (m3/s)    -0.0159      0.060     -0.266      0.790      -0.133       0.101
# L1.precipitation (mm)        0.1771      0.041      4.331      0.000       0.097       0.257
# L2.water_level              30.3920     25.207      1.206      0.228     -19.012      79.796
# L2.inflow_linth (m3/s)      -0.1492      0.184     -0.812      0.417      -0.509       0.211
# L2.outflow_limmat (m3/s)    -0.0969      0.086     -1.132      0.258      -0.265       0.071
# L2.precipitation (mm)       -0.0421      0.051     -0.824      0.410      -0.142       0.058
# L3.water_level              10.4361     25.121      0.415      0.678     -38.801      59.673
# L3.inflow_linth (m3/s)      -0.0722      0.186     -0.388      0.698      -0.437       0.293
# L3.outflow_limmat (m3/s)     0.0177      0.091      0.193      0.847      -0.161       0.197
# L3.precipitation (mm)        0.0705      0.061      1.164      0.245      -0.048       0.189
# L4.water_level             -41.8591     16.965     -2.467      0.014     -75.109      -8.609
# L4.inflow_linth (m3/s)       0.1028      0.115      0.895      0.371      -0.122       0.328
# L4.outflow_limmat (m3/s)     0.0434      0.053      0.821      0.412      -0.060       0.147
# L4.precipitation (mm)        0.0224      0.061      0.365      0.715      -0.098       0.143
#                          Results for equation outflow_limmat (m3/s)
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                 9635.9696        nan        nan        nan         nan         nan
# L1.water_level              47.9093     13.531      3.541      0.000      21.389      74.430
# L1.inflow_linth (m3/s)       0.8204      0.285      2.875      0.004       0.261       1.380
# L1.outflow_limmat (m3/s)     0.2386      0.144      1.661      0.097      -0.043       0.520
# L1.precipitation (mm)        0.4716      0.114      4.148      0.000       0.249       0.694
# L2.water_level             -97.3310     10.705     -9.093      0.000    -118.311     -76.351
# L2.inflow_linth (m3/s)      -0.1662      0.396     -0.420      0.675      -0.943       0.610
# L2.outflow_limmat (m3/s)     0.0814      0.189      0.431      0.666      -0.289       0.452
# L2.precipitation (mm)       -0.0348      0.108     -0.321      0.748      -0.247       0.178
# L3.water_level              65.3951     13.386      4.885      0.000      39.159      91.631
# L3.inflow_linth (m3/s)      -0.4023      0.426     -0.945      0.345      -1.237       0.432
# L3.outflow_limmat (m3/s)     0.1717      0.189      0.906      0.365      -0.200       0.543
# L3.precipitation (mm)        0.0439      0.137      0.320      0.749      -0.225       0.313
# L4.water_level             -39.6732     10.685     -3.713      0.000     -60.615     -18.732
# L4.inflow_linth (m3/s)       0.1221      0.279      0.437      0.662      -0.426       0.670
# L4.outflow_limmat (m3/s)     0.0336      0.126      0.268      0.789      -0.213       0.280
# L4.precipitation (mm)        0.0285      0.132      0.216      0.829      -0.230       0.287
#                           Results for equation precipitation (mm)
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                 2938.6393      0.260   1.13e+04      0.000    2938.130    2939.149
# L1.water_level             -13.9297     33.136     -0.420      0.674     -78.874      51.015
# L1.inflow_linth (m3/s)       0.3340      0.279      1.198      0.231      -0.213       0.880
# L1.outflow_limmat (m3/s)    -0.2218      0.127     -1.752      0.080      -0.470       0.026
# L1.precipitation (mm)        0.1629      0.110      1.482      0.138      -0.053       0.378
# L2.water_level              23.5832     37.270      0.633      0.527     -49.464      96.631
# L2.inflow_linth (m3/s)       0.1909      0.374      0.511      0.610      -0.542       0.924
# L2.outflow_limmat (m3/s)    -0.1238      0.170     -0.730      0.465      -0.456       0.208
# L2.precipitation (mm)        0.2346      0.097      2.421      0.015       0.045       0.424
# L3.water_level              46.7329     20.779      2.249      0.025       6.006      87.460
# L3.inflow_linth (m3/s)      -0.5100      0.326     -1.564      0.118      -1.149       0.129
# L3.outflow_limmat (m3/s)     0.1286      0.143      0.899      0.369      -0.152       0.409
# L3.precipitation (mm)       -0.0293      0.108     -0.270      0.787      -0.242       0.183
# L4.water_level             -63.5960     33.186     -1.916      0.055    -128.640       1.448
# L4.inflow_linth (m3/s)       0.2650      0.217      1.218      0.223      -0.161       0.691
# L4.outflow_limmat (m3/s)     0.0617      0.099      0.620      0.535      -0.133       0.257
# L4.precipitation (mm)        0.0690      0.086      0.800      0.424      -0.100       0.238
#                                                Error covariance matrix
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# sqrt.var.water_level                                   0.0479      0.002     26.418      0.000       0.044       0.051
# sqrt.cov.water_level.inflow_linth (m3/s)               8.2669      0.608     13.605      0.000       7.076       9.458
# sqrt.var.inflow_linth (m3/s)                           8.4342      0.297     28.365      0.000       7.851       9.017
# sqrt.cov.water_level.outflow_limmat (m3/s)            20.5553      1.421     14.461      0.000      17.769      23.341
# sqrt.cov.inflow_linth (m3/s).outflow_limmat (m3/s)     9.1802      1.291      7.108      0.000       6.649      11.711
# sqrt.var.outflow_limmat (m3/s)                        13.4268      0.679     19.781      0.000      12.096      14.757
# sqrt.cov.water_level.precipitation (mm)                8.9803      1.664      5.398      0.000       5.719      12.241
# sqrt.cov.inflow_linth (m3/s).precipitation (mm)        0.9462      1.505      0.629      0.530      -2.003       3.896
# sqrt.cov.outflow_limmat (m3/s).precipitation (mm)      9.3220      1.196      7.797      0.000       6.979      11.665
# sqrt.var.precipitation (mm)                           17.4715      0.849     20.581      0.000      15.808      19.135
# ======================================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.63e+17. Standard errors may be unstable.

# %%
def walk_forward_validation_VAR(train, test, order):
    window=1
    forecast_series = pd.DataFrame(index=test.index, columns=[x for x in range(window)])
    training_data = train.copy()
    for i in test.index:
        model = VARMAX(training_data, order=order).fit()
        forecast_series.loc[i] = model.forecast(window)[0]
        training_data.loc[i] = test.loc[i]
        columns = [f'yt+{x}' for x in forecast_series.columns]
    forecast_series.columns = columns
    return forecast_series.astype(float), model

# %%
twk, tawk = walk_forward_validation_VAR(train_val[['water_level', 'outflow_limmat (m3/s)']], test_val[['water_level', 'outflow_limmat (m3/s)']], (3,1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lunam\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\lunam\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\lunam\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [106], line 1
# ----> 1 twk, tawk = walk_forward_validation_VAR(train_val[['water_level', 'outflow_limmat (m3/s)']], test_val[['water_level', 'outflow_limmat (m3/s)']], (3,1))
#
# Cell In [105], line 7, in walk_forward_validation_VAR(train, test, order)
#       5 for i in test.index:
#       6     model = VARMAX(training_data, order=order).fit()
# ----> 7     forecast_series.loc[i] = model.forecast(window)[0]
#       8     training_data.loc[i] = test.loc[i]
#       9     columns = [f'yt+{x}' for x in forecast_series.columns]
#
# File c:\Users\lunam\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File c:\Users\lunam\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 0

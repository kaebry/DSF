# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dvar_hourly = pd.read_csv("../Data/data_reduced_variables.csv")
dvar_hourly
# Out:
#                         datetime  suction_tension (20cm)  \
# 0      2012-01-01 01:00:00+01:00                   0.500
# 1      2012-01-01 02:00:00+01:00                   0.600
# 2      2012-01-01 03:00:00+01:00                   0.700
# 3      2012-01-01 04:00:00+01:00                   0.800
# 4      2012-01-01 05:00:00+01:00                   1.000
# ...                          ...                     ...
# 60749  2019-11-27 01:00:00+01:00                   4.780
# 60750  2019-11-27 02:00:00+01:00                   3.405
# 60751  2019-11-27 03:00:00+01:00                   4.730
# 60752  2019-11-27 04:00:00+01:00                   4.810
# 60753  2019-11-27 05:00:00+01:00                   4.770
#
#        suction_tension (40cm)  suction_tension (70cm)  water_temperature  \
# 0                       0.600                   1.000           5.900000
# 1                       0.700                   1.000           5.900000
# ...

# %%
dvar_hourly["datetime"] = pd.to_datetime(dvar_hourly['datetime'])
# set DateTime as index
dvar_hourly.set_index("datetime", inplace=True)
dvar_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60754 entries, 2012-01-01 01:00:00+01:00 to 2019-11-27 05:00:00+01:00
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   60754 non-null  float64
#  1   suction_tension (40cm)   60754 non-null  float64
#  2   suction_tension (70cm)   60754 non-null  float64
#  3   water_temperature        60754 non-null  float64
#  4   barometric_pressure_qfe  60754 non-null  float64
#  5   dew_point                60754 non-null  float64
#  6   water_level              60754 non-null  float64
#  7   precipitation (mm)       60754 non-null  float64
#  8   change_rate              60754 non-null  float64
#  9   inflow_linth (m3/s)      60754 non-null  float64
#  10  outflow_limmat (m3/s)    60754 non-null  float64
#  11  evaporation              60754 non-null  float64
# dtypes: float64(12)
# memory usage: 6.0+ MB

# %%
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data_hourly = dvar_hourly[dvar_hourly.columns[i]]
    ax.plot(data_hourly, color='blue', linewidth=1)
    # Decorations
    ax.set_title(dvar_hourly.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
dvar_daily = pd.read_csv("../Data/daily_data.csv")
dvar_daily
# Out:
#       Unnamed: 0  suction_tension (20cm)  suction_tension (40cm)  \
# 0     2012-01-01                1.743478                1.356522
# 1     2012-01-02                2.085417                1.595833
# 2     2012-01-03                2.179167                1.700000
# 3     2012-01-04                1.745833                1.375000
# 4     2012-01-05                1.435417                1.189583
# ...          ...                     ...                     ...
# 2883  2019-11-23                4.255208                3.026875
# 2884  2019-11-24                4.528125                3.240625
# 2885  2019-11-25                4.723958                3.411458
# 2886  2019-11-26                4.853542                3.541250
# 2887  2019-11-27                4.540833                3.430833
#
#       suction_tension (70cm)  water_temperature  barometric_pressure_qfe  \
# 0                   1.504348           6.023188               972.383333
# ...

# %%
dvar_daily["Unnamed: 0"] = pd.to_datetime(dvar_daily['Unnamed: 0'])
# set DateTime as index
dvar_daily.set_index("Unnamed: 0", inplace=True)
dvar_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2888 entries, 2012-01-01 to 2019-11-27
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   2888 non-null   float64
#  1   suction_tension (40cm)   2888 non-null   float64
#  2   suction_tension (70cm)   2888 non-null   float64
#  3   water_temperature        2888 non-null   float64
#  4   barometric_pressure_qfe  2888 non-null   float64
#  5   dew_point                2888 non-null   float64
#  6   water_level              2888 non-null   float64
#  7   inflow_linth (m3/s)      2888 non-null   float64
#  8   outflow_limmat (m3/s)    2888 non-null   float64
#  9   precipitation (mm)       2888 non-null   float64
#  10  change_rate              2887 non-null   float64
#  11  Evapotranspiration (mm)  2888 non-null   float64
# dtypes: float64(12)
# memory usage: 293.3 KB

# %%
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data_daily = dvar_daily[dvar_daily.columns[i]]
    ax.plot(data_daily, color='blue', linewidth=1)
    # Decorations
    ax.set_title(dvar_daily.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
dvar_weekly = pd.read_csv("../Data/weekly_data_copy.csv")
dvar_weekly
# Out:
#                       datetime  suction_tension (20cm)  \
# 0    2012-01-01 00:00:00+00:00                1.743478
# 1    2012-01-08 00:00:00+00:00                1.867262
# 2    2012-01-15 00:00:00+00:00                3.035119
# 3    2012-01-22 00:00:00+00:00                3.742262
# 4    2012-01-29 00:00:00+00:00                1.996429
# ..                         ...                     ...
# 409  2019-11-03 00:00:00+00:00                3.102348
# 410  2019-11-10 00:00:00+00:00                2.272055
# 411  2019-11-17 00:00:00+00:00                3.036545
# 412  2019-11-24 00:00:00+00:00                3.545053
# 413  2019-12-01 00:00:00+00:00                4.706111
#
#      suction_tension (40cm)  suction_tension (70cm)  water_temperature  \
# 0                  1.356522                1.504348           6.023188
# 1                  1.512500                1.658929           5.722718
# 2                  2.651786                2.248214           5.233115
# ...

# %%
dvar_weekly["datetime"] = pd.to_datetime(dvar_weekly['datetime'])
# set DateTime as index
dvar_weekly.set_index("datetime", inplace=True)
dvar_weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 414 entries, 2012-01-01 00:00:00+00:00 to 2019-12-01 00:00:00+00:00
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   414 non-null    float64
#  1   suction_tension (40cm)   414 non-null    float64
#  2   suction_tension (70cm)   414 non-null    float64
#  3   water_temperature        414 non-null    float64
#  4   barometric_pressure_qfe  414 non-null    float64
#  5   dew_point                414 non-null    float64
#  6   water_level              414 non-null    float64
#  7   inflow_linth (m3/s)      414 non-null    float64
#  8   outflow_limmat (m3/s)    414 non-null    float64
#  9   precipitation (mm)       414 non-null    float64
#  10  Evapotranspiration (mm)  414 non-null    float64
#  11  change_rate              413 non-null    float64
# dtypes: float64(12)
# memory usage: 42.0 KB

# %%
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data_weekly = dvar_weekly[dvar_weekly.columns[i]]
    ax.plot(data_weekly, color='blue', linewidth=1)
    # Decorations
    ax.set_title(dvar_weekly.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
dvar_monthly = pd.read_csv("../Data/monthly_data.csv")
dvar_monthly
# Out:
#       datetime  suction_tension (20cm)  suction_tension (40cm)  \
# 0   2012-01-31                2.647908                2.119901
# 1   2012-02-29               20.929298                4.169540
# 2   2012-03-31                6.118768                3.344197
# 3   2012-04-30                8.059861                3.810556
# 4   2012-05-31                9.134409                4.221102
# ..         ...                     ...                     ...
# 90  2019-07-31               17.754590                9.390202
# 91  2019-08-31                7.015074                4.549133
# 92  2019-09-30                7.228299                3.988014
# 93  2019-10-31                3.555907                2.373436
# 94  2019-11-30                3.128505                2.232625
#
#     suction_tension (70cm)  water_temperature  barometric_pressure_qfe  \
# 0                 2.001417           5.229975               975.593403
# ...

# %%
dvar_monthly["datetime"] = pd.to_datetime(dvar_monthly['datetime'])
# set DateTime as index
dvar_monthly.set_index("datetime", inplace=True)
dvar_monthly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 95 entries, 2012-01-31 to 2019-11-30
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   suction_tension (20cm)   95 non-null     float64
#  1   suction_tension (40cm)   95 non-null     float64
#  2   suction_tension (70cm)   95 non-null     float64
#  3   water_temperature        95 non-null     float64
#  4   barometric_pressure_qfe  95 non-null     float64
#  5   dew_point                95 non-null     float64
#  6   water_level              95 non-null     float64
#  7   inflow_linth (m3/s)      95 non-null     float64
#  8   outflow_limmat (m3/s)    95 non-null     float64
#  9   precipitation (mm)       95 non-null     float64
#  10  Evapotranspiration (mm)  95 non-null     float64
#  11  change_rate              94 non-null     float64
# dtypes: float64(12)
# memory usage: 9.6 KB

# %%
fig, axes = plt.subplots(nrows=6, ncols=2, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data_monthly = dvar_monthly[dvar_monthly.columns[i]]
    ax.plot(data_monthly, color='blue', linewidth=1)
    # Decorations
    ax.set_title(dvar_monthly.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
